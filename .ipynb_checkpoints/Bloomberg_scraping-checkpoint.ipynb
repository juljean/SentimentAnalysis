# %%
from selenium.webdriver import Chrome
import csv
from getpass import getpass
from time import sleep
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.common.by import By

# %%
driver = Chrome()
driver.get('https://twitter.com/i/flow/login')

# %%
username = driver.find_element(By.XPATH,'//input[@name = "text"]')
username.send_keys('nad.yul2002@gmail.com')

# %%
username.send_keys(Keys.RETURN)

# %%
my_password = getpass()
# Out:
# ········

# %%
password = driver.find_element(By.XPATH, '//input[@name = "password"]')
password.send_keys(my_password)

# %%
search_input = driver.find_element(By.XPATH, '//input[@aria-label="Search query"]')
search_input.send_keys('Bloomberg')
search_input.send_keys(Keys.RETURN)

# %%
driver.find_element_by_link_text('People').click()
nytimes_input = driver.find_element(By.XPATH, '//span[text() = "Bloomberg"]')
nytimes_input.click()
# Out:
# <ipython-input-30-54116ccab38c>:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_link_text('People').click()

# %%
cards = driver.find_elements(By.XPATH, './/article[@data-testid="tweet"]')
card = cards[0]

# %%
#Tweet Publisher
card.find_element(By.XPATH, './/span').text
# Out:
# 'Bloomberg'

# %%
#Tweet Date
card.find_element(By.XPATH, './/time').get_attribute('datetime')
# Out:
# '2021-12-27T18:36:05.000Z'

# %%
#Tweet Content 
comment = card.find_element(By.XPATH, './/div[1]/div[1]/div[1]/div[2]/div[2]/div[2]').text
responding = card.find_element(By.XPATH, './/div[1]/div[1]/div[2]').text
comment+responding
# Out:
# 'The U.K. government won’t introduce stricter Covid-19 restrictions in England before the end of the year despite the rapid spread of the omicron variant\nbloomberg.com\nU.K. Rules Out Tighter Covid Restrictions Before New Year\n3\n5\n21Bloomberg\n@business\n·\n11m\nThe U.K. government won’t introduce stricter Covid-19 restrictions in England before the end of the year despite the rapid spread of the omicron variant\nbloomberg.com\nU.K. Rules Out Tighter Covid Restrictions Before New Year\n3\n5\n21'

# %%
#Tweet Reply Count
card.find_element(By.XPATH, './/div[@data-testid="reply"]').text
# Out:
# '3'

# %%
#Tweet Retweet
card.find_element(By.XPATH, './/div[@data-testid="retweet"]').text
# Out:
# '5'

# %%
#Tweet Likes
card.find_element(By.XPATH, './/div[@data-testid="like"]').text
# Out:
# '21'

# %%
def get_tweet_data(card):
    """Extract data from tweet"""
    username = card.find_element(By.XPATH, './/span').text
    handle = card.find_element(By.XPATH, './/span[contains(text(), "@")]').text
    try:
        postdate = card.find_element(By.XPATH, './/time').get_attribute('datetime')
    except NoSuchElementException:
        return
    comment = card.find_element(By.XPATH, './/div[1]/div[1]/div[1]/div[2]/div[2]/div[2]').text
    responding = card.find_element(By.XPATH, './/div[1]/div[1]/div[2]').text
    text = comment+responding
    reply_cnt = card.find_element(By.XPATH, './/div[@data-testid="reply"]').text
    retweet_cnt = card.find_element(By.XPATH, './/div[@data-testid="retweet"]').text
    likes_cnt = card.find_element(By.XPATH, './/div[@data-testid="like"]').text
    
    tweet = (username, handle, postdate, text, reply_cnt, retweet_cnt, likes_cnt)
    return tweet

# %%
get_tweet_data(card)
# Out:
# ('Bloomberg',
#  '@business',
#  '2021-12-27T18:36:05.000Z',
#  'The U.K. government won’t introduce stricter Covid-19 restrictions in England before the end of the year despite the rapid spread of the omicron variant\nbloomberg.com\nU.K. Rules Out Tighter Covid Restrictions Before New Year\n3\n5\n21Bloomberg\n@business\n·\n11m\nThe U.K. government won’t introduce stricter Covid-19 restrictions in England before the end of the year despite the rapid spread of the omicron variant\nbloomberg.com\nU.K. Rules Out Tighter Covid Restrictions Before New Year\n3\n5\n21',
#  '3',
#  '5',
#  '21')

# %%
tweet_data = []

for card in cards:
    data = get_tweet_data(card)
    if data:
        tweet_data.append(data)

tweet_data
# Out:
# [('Bloomberg',
#   '@business',
#   '2021-12-27T18:36:05.000Z',
#   'The U.K. government won’t introduce stricter Covid-19 restrictions in England before the end of the year despite the rapid spread of the omicron variant\nbloomberg.com\nU.K. Rules Out Tighter Covid Restrictions Before New Year\n3\n5\n21Bloomberg\n@business\n·\n11m\nThe U.K. government won’t introduce stricter Covid-19 restrictions in England before the end of the year despite the rapid spread of the omicron variant\nbloomberg.com\nU.K. Rules Out Tighter Covid Restrictions Before New Year\n3\n5\n21',
#   '3',
#   '5',
#   '21'),
#  ('Bloomberg Retweeted',
#   '@BloombergLive',
#   '2021-12-27T18:25:44.000Z',
#   'ICYMI: On crypto, "I don\'t think we\'ve had our Netscape moment. I believe our best days are yet to come." Partner \n@sequoia\n Pat Grady tells \n@business\n\' \n@mcbridesg\n. Watch the  #BloombergTech Summit on-demand here! http://bloom.bg/3F0m31F\n7\n12\n18Bloomberg Retweeted',
#   '7',
#   '12',
#   '18'),
#  ('Bloomberg',
#   '@business',
#   '2021-12-27T18:25:04.000Z',
#   'English sparkling wine has been gaining prestige in recent years, with some experts comparing it to Champagne in taste and quality https://trib.al/MPDqdlO via AP\nbloomberg.com\nFor Celebrations, English Fizz Is on the Rise\nLondon (AP) -- English sparkling wine has been gaining prestige in recent years, with some experts comparing it to Champagne in taste and quality.\n5\n9\n14Bloomberg\n@business\n·\n22m\nEnglish sparkling wine has been gaining prestige in recent years, with some experts comparing it to Champagne in taste and quality https://trib.al/MPDqdlO via AP\nbloomberg.com\nFor Celebrations, English Fizz Is on the Rise\nLondon (AP) -- English sparkling wine has been gaining prestige in recent years, with some experts comparing it to Champagne in taste and quality.\n5\n9\n14',
#   '5',
#   '9',
#   '14')]

# %%
driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')

# %%
#get all tweets on the page

data = []
tweet_ids = set()
last_position = driver.execute_script("return window.pageYOffset;")
scrolling = True

while scrolling:
    page_cards = driver.find_elements(By.XPATH, './/article[@data-testid="tweet"]')
    for card in page_cards[-15:]:
        tweet = get_tweet_data(card)
        if tweet:
            tweet_id = ''.join(tweet)
            if tweet_id not in tweet_ids:
                tweet_ids.add(tweet_id)
                data.append(tweet)
    
    scroll_attempt = 0
    while True:            
        driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
        sleep(1)
        curr_position = driver.execute_script("return window.pageYOffset;")
        if last_position == curr_position:
            scroll_attempt += 1

            if scroll_attempt >=3:
                scrolling = False
                break
            else:
                sleep(2)
        else:
            last_position = curr_position
            break

# %%
data
# Out:
# [('Bloomberg',
#   '@business',
#   '2021-12-27T17:08:04.000Z',
#   'New research shows insider trading is everywhere. So far, no one seems to care\nbloomberg.com\n‘Most Americans Today Believe the Stock Market Is Rigged, and They’re Right’\nNew research shows insider trading is everywhere. So far, no one seems to care.\n59\n185\n420Bloomberg\n@business\n·\n1h\nNew research shows insider trading is everywhere. So far, no one seems to care\nbloomberg.com\n‘Most Americans Today Believe the Stock Market Is Rigged, and They’re Right’\nNew research shows insider trading is everywhere. So far, no one seems to care.\n59\n185\n420',
#   '59',
#   '185',
#   '420'),
#  ('Bloomberg',
#   '@business',
#   '2021-12-27T17:05:09.000Z',
#   'Fauci says a domestic travel vaccination rule should be considered as the omicron variant spreads around the U.S.\nbloomberg.com\nFauci Says Domestic Travel Vaccination Rule Should Be Considered\nPresident Joe Biden’s medical adviser said a domestic travel vaccination rule should be considered as the omicron variant fuels record Covid-19 case loads in some states and holiday travel continues...\n27\n26\n51Bloomberg\n@business\n·\n1h\nFauci says a domestic travel vaccination rule should be considered as the omicron variant spreads around the U.S.\nbloomberg.com\nFauci Says Domestic Travel Vaccination Rule Should Be Considered\nPresident Joe Biden’s medical adviser said a domestic travel vaccination rule should be considered as the omicron variant fuels record Covid-19 case loads in some states and holiday travel continues...\n27\n26\n51',
#   '27',
#   '26',
#   '51'),
#  ('Bloomberg',
#   '@business',
#   '2021-12-27T17:03:05.000Z',
#   '“It used to be an on-site day care center was about recruiting and retention,” says Stephen Kramer, Bright Horizon’s CEO. “Now it’s also being seen as a reason employees are coming back to the office.” https://trib.al/FDRtWcu via \n@BW\nbloomberg.com\nBright Horizons Is Betting Kids Will Return to the Office, Even If Parents Stay Home\nAs the child-care industry crumbles, the largest provider of on-site daycare makes its move on corporate America.\n1\n4\n16Bloomberg\n@business\n·\n1h\n“It used to be an on-site day care center was about recruiting and retention,” says Stephen Kramer, Bright Horizon’s CEO. “Now it’s also being seen as a reason employees are coming back to the office.” https://trib.al/FDRtWcu via \n@BW\nbloomberg.com\nBright Horizons Is Betting Kids Will Return to the Office, Even If Parents Stay Home\nAs the child-care industry crumbles, the largest provider of on-site daycare makes its move on corporate America.\n1\n4\n16',
#   '1',
#   '4',
#   '16'),
#  ('Bloomberg',
#   '@business',
#   '2021-12-27T17:03:05.000Z',
#   'As a blockbuster year for cryptocurrencies ticks to a close, some of the smallest coins are having a moment\nbloomberg.com\nBitcoin Loses Luster to Alternative Coins in Up Day for Crypto\nAs a blockbuster year for cryptocurrencies ticks to a close, some of the smallest coins are having a moment.\n2\n8\n11Bloomberg\n@business\n·\n1h\nAs a blockbuster year for cryptocurrencies ticks to a close, some of the smallest coins are having a moment\nbloomberg.com\nBitcoin Loses Luster to Alternative Coins in Up Day for Crypto\nAs a blockbuster year for cryptocurrencies ticks to a close, some of the smallest coins are having a moment.\n2\n8\n11',
#   '2',
#   '8',
#   '11'),
#  ('Bloomberg Retweeted',
#   '@Quicktake',
#   '2021-12-27T16:41:13.000Z',
#   '2 dams broke Sunday in northeastern Brazil, causing a strong flash flood that forced thousands to flee their homes. Officials are trying to distribute food, mattresses and warm clothing to flood victims\n0:45\n12.4K views\n1\n31\n34Bloomberg Retweeted',
#   '1',
#   '31',
#   '34'),
#  ('Bloomberg',
#   '@business',
#   '2021-12-27T17:02:03.000Z',
#   'A firm founded by Warren Buffett’s grandson is selling rich Asians on the idea of doing well by doing good https://trib.al/B0ULJPK via \n@BW\nbloomberg.com\nRich Asian Families Are Pouring Millions Into Impact Investing\nI(x) Investments, a firm co-founded by Warren Buffett’s grandson, is among those turning East to put private capital to work addressing issues such as climate change.\n2\n15\n26Bloomberg\n@business\n·\n1h\nA firm founded by Warren Buffett’s grandson is selling rich Asians on the idea of doing well by doing good https://trib.al/B0ULJPK via \n@BW\nbloomberg.com\nRich Asian Families Are Pouring Millions Into Impact Investing\nI(x) Investments, a firm co-founded by Warren Buffett’s grandson, is among those turning East to put private capital to work addressing issues such as climate change.\n2\n15\n26',
#   '2',
#   '15',
#   '26'),
#  ('Bloomberg',
#   '@business',
#   '2021-12-27T17:00:27.000Z',
#   "Don't look now, but french fries are at risk of becoming the latest victim of a strained food supply chain\nbloomberg.com\nFrench Fry Shortage Hits Some Restaurants in Latest Supply Snag\nThe message posted to Instagram late Tuesday by J.G. Melon, a revered New York City burger joint, surely came as a shock to its many fans.\n9\n25\n45Bloomberg\n@business\n·\n1h\nDon't look now, but french fries are at risk of becoming the latest victim of a strained food supply chain\nbloomberg.com\nFrench Fry Shortage Hits Some Restaurants in Latest Supply Snag\nThe message posted to Instagram late Tuesday by J.G. Melon, a revered New York City burger joint, surely came as a shock to its many fans.\n9\n25\n45",
#   '9',
#   '25',
#   '45'),
#  ('Bloomberg',
#   '@business',
#   '2021-12-27T16:59:04.000Z',
#   'Activist investor Starboard disclosed a stake in website services company GoDaddy Inc. and said it may push for changes to improve the stock’s performance.\nbloomberg.com\nActivist Investor Starboard Is Pushing for Changes at GoDaddy\nActivist investor Starboard Value disclosed a stake in website services company GoDaddy Inc. and said it may push for changes to improve the stock’s performance.\n1\n5\n9Bloomberg\n@business\n·\n1h\nActivist investor Starboard disclosed a stake in website services company GoDaddy Inc. and said it may push for changes to improve the stock’s performance.\nbloomberg.com\nActivist Investor Starboard Is Pushing for Changes at GoDaddy\nActivist investor Starboard Value disclosed a stake in website services company GoDaddy Inc. and said it may push for changes to improve the stock’s performance.\n1\n5\n9',
#   '1',
#   '5',
#   '9'),
#  ('Bloomberg Retweeted',
#   '@luxury',
#   '2021-12-27T16:25:25.000Z',
#   'A clubby Korean steakhouse, Spanish fare in an elevated garden, and superior sushi are all included in our list of the 13 best new restaurants in Miami, as chosen by top chefs\nbloomberg.com\nThe Best New Restaurants in Miami, as Chosen by Top Chefs\nThe 13 spots include a clubby Korean steakhouse, Spanish fare in an elevated garden, and superior sushi.\n9\n15Bloomberg Retweeted',
#   '',
#   '9',
#   '15'),
#  ('Bloomberg',
#   '@business',
#   '2021-12-27T16:22:03.000Z',
#   'Municipal-bond investors seeking shelter from rising rates in 2022 should look to housing bonds, JPMorgan says\nbloomberg.com\nJPMorgan Sees Muni Housing Bonds Besting Other Sectors Next Year\nMunicipal-bond investors seeking shelter from rising rates in 2022 should look to housing bonds, according to JPMorgan Chase & Co.’s lead muni strategist.\n3\n10\n15Bloomberg\n@business\n·\n2h\nMunicipal-bond investors seeking shelter from rising rates in 2022 should look to housing bonds, JPMorgan says\nbloomberg.com\nJPMorgan Sees Muni Housing Bonds Besting Other Sectors Next Year\nMunicipal-bond investors seeking shelter from rising rates in 2022 should look to housing bonds, according to JPMorgan Chase & Co.’s lead muni strategist.\n3\n10\n15',
#   '3',
#   '10',
#   '15'),
#  ('Bloomberg',
#   '@business',
#   '2021-12-27T16:17:20.000Z',
#   'Meta shares are rising Monday, with the Facebook parent leading an advance among big-cap tech and internet stocks on signs of strong holiday demand for its Oculus virtual reality headset\nbloomberg.com\nMeta Gains as KeyBanc Sees Strong Holiday Sales for Oculus Headset\n6\n17\n34Bloomberg\n@business\n·\n2h\nMeta shares are rising Monday, with the Facebook parent leading an advance among big-cap tech and internet stocks on signs of strong holiday demand for its Oculus virtual reality headset\nbloomberg.com\nMeta Gains as KeyBanc Sees Strong Holiday Sales for Oculus Headset\n6\n17\n34',
#   '6',
#   '17',
#   '34'),
#  ('Bloomberg',
#   '@business',
#   '2021-12-27T16:10:06.000Z',
#   'The hardest part about developing a super-vaccine for all coronaviruses could be finding a way to pay for it\nbloomberg.com\nThe Hunt for a Single Shot to Defeat Omicron and All Coronaviruses\nThe hardest part about developing a super-vaccine for all coronaviruses could be finding a way to pay for it.\n20\n18\n35Bloomberg\n@business\n·\n2h\nThe hardest part about developing a super-vaccine for all coronaviruses could be finding a way to pay for it\nbloomberg.com\nThe Hunt for a Single Shot to Defeat Omicron and All Coronaviruses\nThe hardest part about developing a super-vaccine for all coronaviruses could be finding a way to pay for it.\n20\n18\n35',
#   '20',
#   '18',
#   '35'),
#  ('Bloomberg',
#   '@business',
#   '2021-12-27T16:10:05.000Z',
#   'More American males aged 25-34 are living in a parent’s home, and fewer are participating in the labor force https://trib.al/WH3xNLc via \n@BW\nbloomberg.com\nFewer Young Men Are in the Labor Force. More Are Living at Home\nFor 25- to 34-year-olds, the two trends add up to a failure to launch.\n10\n41\n41Bloomberg\n@business\n·\n2h\nMore American males aged 25-34 are living in a parent’s home, and fewer are participating in the labor force https://trib.al/WH3xNLc via \n@BW\nbloomberg.com\nFewer Young Men Are in the Labor Force. More Are Living at Home\nFor 25- to 34-year-olds, the two trends add up to a failure to launch.\n10\n41\n41',
#   '10',
#   '41',
#   '41'),
#  ('Bloomberg',
#   '@business',
#   '2021-12-27T16:05:07.000Z',
#   "The legacy of Archbishop Desmond Tutu's activism for equality continues to reverberate among young South Africans, many of whom were not born when the clergyman battled apartheid https://trib.al/lhZJyNd via AP\nbloomberg.com\nYoung South Africans Learn of Tutu's Activism for Equality\nJohannesburg (AP) -- The legacy of Archbishop Desmond Tutu's activism for equality continues to reverberate among young South Africans, many of whom were not born when the clergyman battled apartheid.\n6\n9\n34Bloomberg\n@business\n·\n2h\nThe legacy of Archbishop Desmond Tutu's activism for equality continues to reverberate among young South Africans, many of whom were not born when the clergyman battled apartheid https://trib.al/lhZJyNd via AP\nbloomberg.com\nYoung South Africans Learn of Tutu's Activism for Equality\nJohannesburg (AP) -- The legacy of Archbishop Desmond Tutu's activism for equality continues to reverberate among young South Africans, many of whom were not born when the clergyman battled apartheid.\n6\n9\n34",
#   '6',
#   '9',
#   '34'),
#  ('Bloomberg',
#   '@business',
#   '2021-12-27T16:05:06.000Z',
#   "A one-time parts supplier for GM remade itself as a tech company. Now it faces competition from carmakers and Silicon Valley alike.\nbloomberg.com\nSilicon Valley’s Push Into Cars Is Testing Aptiv's Tech Makeover\nAptiv has morphed from bankrupt GM supplier to shrewd tech company. Now, as carmakers change their playbooks, it may have to adapt again. \n4\n4\n17Bloomberg\n@business\n·\n2h\nA one-time parts supplier for GM remade itself as a tech company. Now it faces competition from carmakers and Silicon Valley alike.\nbloomberg.com\nSilicon Valley’s Push Into Cars Is Testing Aptiv's Tech Makeover\nAptiv has morphed from bankrupt GM supplier to shrewd tech company. Now, as carmakers change their playbooks, it may have to adapt again. \n4\n4\n17",
#   '4',
#   '4',
#   '17'),
#  ('Bloomberg Retweeted',
#   '@BW',
#   '2021-12-27T16:03:55.000Z',
#   'Bright Horizons is betting kids will return to the office, even if parents stay home\nbloomberg.com\nBright Horizons Is Betting Kids Will Return to the Office, Even If Parents Stay Home\nAs the child-care industry crumbles, the largest provider of on-site daycare makes its move on corporate America.\n5\n13\n27Bloomberg Retweeted',
#   '5',
#   '13',
#   '27'),
#  ('Bloomberg',
#   '@business',
#   '2021-12-27T15:59:02.000Z',
#   'Miami is getting a new 80-story luxury condo tower in its financial district\nbloomberg.com\nMiami’s Financial District to Get Another New Luxury Condo Tower\nMiami-based developer Mast Capital is planning a new 80-story luxury condo tower in the city’s financial district, betting on new arrivals to keep demand strong in a red-hot market.\n9\n11\n57Bloomberg\n@business\n·\n2h\nMiami is getting a new 80-story luxury condo tower in its financial district\nbloomberg.com\nMiami’s Financial District to Get Another New Luxury Condo Tower\nMiami-based developer Mast Capital is planning a new 80-story luxury condo tower in the city’s financial district, betting on new arrivals to keep demand strong in a red-hot market.\n9\n11\n57',
#   '9',
#   '11',
#   '57'),
#  ('Bloomberg',
#   '@business',
#   '2021-12-27T15:55:05.000Z',
#   "Bad news, stock traders: You're not getting Friday off for New Year's (or Monday, either). \n\nHere's why\nbloomberg.com\nSorry, Wall Street. You're Going to Have to Work New Year's Eve\nIt’s the Grinch That Stole New Year’s.\n3\n13\n25Bloomberg\n@business\n·\n2h\nBad news, stock traders: You're not getting Friday off for New Year's (or Monday, either). \n\nHere's why\nbloomberg.com\nSorry, Wall Street. You're Going to Have to Work New Year's Eve\nIt’s the Grinch That Stole New Year’s.\n3\n13\n25",
#   '3',
#   '13',
#   '25'),
#  ('Bloomberg',
#   '@business',
#   '2021-12-27T15:01:07.000Z',
#   "New York City Mayor Bill de Blasio says that he'll decide “very, very soon” on whether to run for governor\nbloomberg.com\nNYC’s Mayor Bill De Blasio Says He’ll Decide ‘Very Soon’ on Governor Run\nNew York City Mayor Bill de Blasio said Monday that he will decide “very, very soon” on whether to run for governor of New York state.\n22\n19\n37Bloomberg\n@business\n·\n3h\nNew York City Mayor Bill de Blasio says that he'll decide “very, very soon” on whether to run for governor\nbloomberg.com\nNYC’s Mayor Bill De Blasio Says He’ll Decide ‘Very Soon’ on Governor Run\nNew York City Mayor Bill de Blasio said Monday that he will decide “very, very soon” on whether to run for governor of New York state.\n22\n19\n37",
#   '22',
#   '19',
#   '37'),
#  ('Bloomberg',
#   '@business',
#   '2021-12-27T14:58:03.000Z',
#   "Almost all NBA teams are dealing with at least one known case of Covid-related issues\nbloomberg.com\nNBA Covid Cases Still Rising as Expanded Testing Begins\n(AP) -- The way Miami's Caleb Martin sees things, he's lucky.\n5\n7\n21Bloomberg\n@business\n·\n3h\nAlmost all NBA teams are dealing with at least one known case of Covid-related issues\nbloomberg.com\nNBA Covid Cases Still Rising as Expanded Testing Begins\n(AP) -- The way Miami's Caleb Martin sees things, he's lucky.\n5\n7\n21",
#   '5',
#   '7',
#   '21'),
#  ('Bloomberg',
#   '@business',
#   '2021-12-27T14:57:03.000Z',
#   'India has barred the Missionaries of Charity, the Catholic religious order and philanthropic organization started by Mother Teresa, from accessing foreign donations for not meeting eligibility conditions under local laws\nbloomberg.com\nMother Teresa’s Charity Barred From Receiving Foreign Funds\n5\n21\n33Bloomberg\n@business\n·\n3h\nIndia has barred the Missionaries of Charity, the Catholic religious order and philanthropic organization started by Mother Teresa, from accessing foreign donations for not meeting eligibility conditions under local laws\nbloomberg.com\nMother Teresa’s Charity Barred From Receiving Foreign Funds\n5\n21\n33',
#   '5',
#   '21',
#   '33'),
#  ('Bloomberg',
#   '@business',
#   '2021-12-27T14:49:05.000Z',
#   'E.O. Wilson, the former Harvard University biologist and Pulitzer Prize winner, has died. He was 92\nbloomberg.com\nE.O. Wilson, Known as ‘Father of Biodiversity,’ Dies at 92\nE.O. Wilson, the former Harvard University biologist and Pulitzer Prize winner whose study of ants and human behavior made him one of the world’s most influential scientists and prompted his calls...\n4\n39\n62Bloomberg\n@business\n·\n3h\nE.O. Wilson, the former Harvard University biologist and Pulitzer Prize winner, has died. He was 92\nbloomberg.com\nE.O. Wilson, Known as ‘Father of Biodiversity,’ Dies at 92\nE.O. Wilson, the former Harvard University biologist and Pulitzer Prize winner whose study of ants and human behavior made him one of the world’s most influential scientists and prompted his calls...\n4\n39\n62',
#   '4',
#   '39',
#   '62'),
#  ('Bloomberg',
#   '@business',
#   '2021-12-27T14:40:08.000Z',
#   'Indonesia is building a hospital that will be run in partnership with U.S.-based Mayo Clinic as part of a bid to recoup $7 billion in outbound medical tourism\nbloomberg.com\nJokowi Builds Hospital to Recoup $7 Billion in Medical Tourism\nIndonesia is building a hospital that will be run in partnership with U.S.-based Mayo Clinic as part of a bid to recoup $7 billion in outbound medical tourism.\n1\n19\n38Bloomberg\n@business\n·\n4h\nIndonesia is building a hospital that will be run in partnership with U.S.-based Mayo Clinic as part of a bid to recoup $7 billion in outbound medical tourism\nbloomberg.com\nJokowi Builds Hospital to Recoup $7 Billion in Medical Tourism\nIndonesia is building a hospital that will be run in partnership with U.S.-based Mayo Clinic as part of a bid to recoup $7 billion in outbound medical tourism.\n1\n19\n38',
#   '1',
#   '19',
#   '38'),
#  ('Bloomberg Retweeted',
#   '@luxury',
#   '2021-12-27T14:37:06.000Z',
#   'New York City’s museums, concerts and Broadway shows are desperately trying to keep their doors open despite a surge in Covid-19 cases\nbloomberg.com\nNYC’s Covid Surge Overtakes Broadway Shows, Museums Trying to Stay Open\nNew York City’s museums, concerts and Broadway theaters are desperately trying to keep their doors open amid a surge in Covid-19 cases, but the onslaught is overwhelming a tourism industry that had...\n3\n8\n17Bloomberg Retweeted',
#   '3',
#   '8',
#   '17'),
#  ('Bloomberg',
#   '@business',
#   '2021-12-27T14:28:05.000Z',
#   'Microsoft and Salesforce are vying with software startups to help businesses improve customer service, targeting once-backwater call centers and creating a new way to seamlessly communicate with consumers\nbloomberg.com\nMicrosoft, Salesforce Battle to Revitalize Customer Service\nOnce-backwater call centers seen as ‘gold mine’ for software makers\n4\n10\n47Bloomberg\n@business\n·\n4h\nMicrosoft and Salesforce are vying with software startups to help businesses improve customer service, targeting once-backwater call centers and creating a new way to seamlessly communicate with consumers\nbloomberg.com\nMicrosoft, Salesforce Battle to Revitalize Customer Service\nOnce-backwater call centers seen as ‘gold mine’ for software makers\n4\n10\n47',
#   '4',
#   '10',
#   '47'),
#  ('Bloomberg',
#   '@business',
#   '2021-12-27T14:27:03.000Z',
#   'Venus Aerospace wants to get passengers anywhere in an hour by rocketing them to the edge of the atmosphere https://trib.al/eXT40vm via \n@BW\nbloomberg.com\nSpace Plane Startup Promises One-Hour Rides to Anywhere on Earth\nVenus Aerospace is building a passenger aircraft that can hit 12 times the speed of sound.\n5\n10\n15Bloomberg\n@business\n·\n4h\nVenus Aerospace wants to get passengers anywhere in an hour by rocketing them to the edge of the atmosphere https://trib.al/eXT40vm via \n@BW\nbloomberg.com\nSpace Plane Startup Promises One-Hour Rides to Anywhere on Earth\nVenus Aerospace is building a passenger aircraft that can hit 12 times the speed of sound.\n5\n10\n15',
#   '5',
#   '10',
#   '15'),
#  ('Bloomberg',
#   '@business',
#   '2021-12-27T14:21:04.000Z',
#   'Didi Global shares are falling Monday after the Financial Times reported that current and former employees of the Chinese ride-hailing giant have been banned from selling the stock\nbloomberg.com\nDidi Shares Slump After Insiders Blocked From Selling Stock\n3\n14\n20Bloomberg\n@business\n·\n4h\nDidi Global shares are falling Monday after the Financial Times reported that current and former employees of the Chinese ride-hailing giant have been banned from selling the stock\nbloomberg.com\nDidi Shares Slump After Insiders Blocked From Selling Stock\n3\n14\n20',
#   '3',
#   '14',
#   '20'),
#  ('Bloomberg',
#   '@business',
#   '2021-12-27T13:49:04.000Z',
#   'A series of developments in Japan is raising new concerns about xenophobia in Asia’s second-largest economy\nbloomberg.com\nXenophobia Spills Into Japan’s Covid-Era Debate on Immigration\nAging nation has sought to fill gaps with foreign workers\n1\n13\n24Bloomberg\n@business\n·\n4h\nA series of developments in Japan is raising new concerns about xenophobia in Asia’s second-largest economy\nbloomberg.com\nXenophobia Spills Into Japan’s Covid-Era Debate on Immigration\nAging nation has sought to fill gaps with foreign workers\n1\n13\n24',
#   '1',
#   '13',
#   '24'),
#  ('Bloomberg',
#   '@business',
#   '2021-12-27T13:27:04.000Z',
#   'Left out of early vaccine trials and faced with confusing messages and misinformation on the dangers to their unborn children, a disproportionately large number of pregnant women have steered clear of Covid shots\nbloomberg.com\nPregnant Women Come Last: When Vaccine Doubts Prove Fatal\nHere’s the latest news from the pandemic.\n6\n9\n16Bloomberg\n@business\n·\n5h\nLeft out of early vaccine trials and faced with confusing messages and misinformation on the dangers to their unborn children, a disproportionately large number of pregnant women have steered clear of Covid shots\nbloomberg.com\nPregnant Women Come Last: When Vaccine Doubts Prove Fatal\nHere’s the latest news from the pandemic.\n6\n9\n16',
#   '6',
#   '9',
#   '16'),
#  ('Bloomberg',
#   '@business',
#   '2021-12-27T13:26:04.000Z',
#   'Boss want you back in the office? Here’s how to keep a hybrid arrangement beneficial to everyone https://trib.al/3fmyNB3 via \n@BW\nbloomberg.com\nFour Ways to Keep Working From Home When the Boss Wants You Back\nManaging a hybrid schedule requires more care as companies start to ask employees to return to the office.\n3\n12\n25Bloomberg\n@business\n·\n5h\nBoss want you back in the office? Here’s how to keep a hybrid arrangement beneficial to everyone https://trib.al/3fmyNB3 via \n@BW\nbloomberg.com\nFour Ways to Keep Working From Home When the Boss Wants You Back\nManaging a hybrid schedule requires more care as companies start to ask employees to return to the office.\n3\n12\n25',
#   '3',
#   '12',
#   '25'),
#  ('Bloomberg',
#   '@business',
#   '2021-12-27T13:22:51.000Z',
#   'Defending Champ US Holds Off Slovakia to Open World Juniors\nbloomberg.com\nDefending Champ US Holds Off Slovakia to Open World Juniors\nRed Deer, Alberta (AP) -- Boston University goalie Drew Commesso made 23 saves and the defending champion United States opened the world junior hockey championship with a 3-2 victory over Slovakia on...\n3\n7\n16Bloomberg\n@business\n·\n5h\nDefending Champ US Holds Off Slovakia to Open World Juniors\nbloomberg.com\nDefending Champ US Holds Off Slovakia to Open World Juniors\nRed Deer, Alberta (AP) -- Boston University goalie Drew Commesso made 23 saves and the defending champion United States opened the world junior hockey championship with a 3-2 victory over Slovakia on...\n3\n7\n16',
#   '3',
#   '7',
#   '16'),
#  ('Bloomberg',
#   '@business',
#   '2021-12-27T13:21:04.000Z',
#   "Here's what faces travelers arriving at Hong Kong's spartan, tightly-secured government-run Covid camp\nbloomberg.com\nWhat Quarantine Is Like Inside Hong Kong's Bleak, High-Security Camp\nOmicron means more travelers, including those from the U.S., must isolate at the government-run facility\n6\n23\n27Bloomberg\n@business\n·\n5h\nHere's what faces travelers arriving at Hong Kong's spartan, tightly-secured government-run Covid camp\nbloomberg.com\nWhat Quarantine Is Like Inside Hong Kong's Bleak, High-Security Camp\nOmicron means more travelers, including those from the U.S., must isolate at the government-run facility\n6\n23\n27",
#   '6',
#   '23',
#   '27'),
#  ('Bloomberg',
#   '@business',
#   '2021-12-27T13:19:28.000Z',
#   "Iraq’s top court rejects an appeal filed by Iran-backed factions contesting the results of country's parliamentary elections held in October, AP reports\nbloomberg.com\nIraq’s Top Court Rejects Appeal Contesting Election Results\nBaghdad (AP) -- Iraq’s top court on Monday rejected an appeal filed by Iran-backed factions contesting the results of country's parliamentary elections held in October. The development marked another...\n3\n6\n9Bloomberg\n@business\n·\n5h\nIraq’s top court rejects an appeal filed by Iran-backed factions contesting the results of country's parliamentary elections held in October, AP reports\nbloomberg.com\nIraq’s Top Court Rejects Appeal Contesting Election Results\nBaghdad (AP) -- Iraq’s top court on Monday rejected an appeal filed by Iran-backed factions contesting the results of country's parliamentary elections held in October. The development marked another...\n3\n6\n9",
#   '3',
#   '6',
#   '9'),
#  ('Bloomberg',
#   '@business',
#   '2021-12-27T13:13:06.000Z',
#   'The bottom 90% of Americans are borrowing from the top 1% https://trib.al/6n4vzrJ via \n@BW\nbloomberg.com\nThe Bottom 90% of Americans Are Borrowing From the Top 1%\nThe savings of the rich are recycled into household and government debt.\n15\n47\n85Bloomberg\n@business\n·\n5h\nThe bottom 90% of Americans are borrowing from the top 1% https://trib.al/6n4vzrJ via \n@BW\nbloomberg.com\nThe Bottom 90% of Americans Are Borrowing From the Top 1%\nThe savings of the rich are recycled into household and government debt.\n15\n47\n85',
#   '15',
#   '47',
#   '85'),
#  ('Bloomberg',
#   '@business',
#   '2021-12-27T13:03:37.000Z',
#   'British police are investigating a video linked to a man armed with a crossbow who was arrested at Windsor Castle on Christmas Day, AP reports\nbloomberg.com\nPolice Probe Video Linked to Windsor Castle Christmas Breach\nLondon (AP) -- British police said Monday they were investigating a video linked to a man armed with a crossbow who was arrested at Windsor Castle on Christmas Day.\n6\n15\n20Bloomberg\n@business\n·\n5h\nBritish police are investigating a video linked to a man armed with a crossbow who was arrested at Windsor Castle on Christmas Day, AP reports\nbloomberg.com\nPolice Probe Video Linked to Windsor Castle Christmas Breach\nLondon (AP) -- British police said Monday they were investigating a video linked to a man armed with a crossbow who was arrested at Windsor Castle on Christmas Day.\n6\n15\n20',
#   '6',
#   '15',
#   '20'),
#  ('Bloomberg',
#   '@business',
#   '2021-12-27T13:03:23.000Z',
#   'The Democratic Republic of Congo, a nation with one of the world’s lowest coronavirus inoculation rates, is planning to vaccinate 2 million people against cholera in 6 days\nbloomberg.com\nCovid Vaccination-Laggard Congo Plans Rapid Cholera Inoculations\nThe Democratic Republic of Congo, a nation with one of the world’s lowest coronavirus inoculation rates, is planning to vaccinate 2 million people against cholera in six days, according to a statem...\n5\n15\n22Bloomberg\n@business\n·\n5h\nThe Democratic Republic of Congo, a nation with one of the world’s lowest coronavirus inoculation rates, is planning to vaccinate 2 million people against cholera in 6 days\nbloomberg.com\nCovid Vaccination-Laggard Congo Plans Rapid Cholera Inoculations\nThe Democratic Republic of Congo, a nation with one of the world’s lowest coronavirus inoculation rates, is planning to vaccinate 2 million people against cholera in six days, according to a statem...\n5\n15\n22',
#   '5',
#   '15',
#   '22'),
#  ('Bloomberg',
#   '@business',
#   '2021-12-27T12:11:02.000Z',
#   'The 13 best new restaurants in Miami, as chosen by top chefs\nbloomberg.com\nThe Best New Restaurants in Miami, as Chosen by Top Chefs\nThe 13 spots include a clubby Korean steakhouse, Spanish fare in an elevated garden, and superior sushi.\n3\n6\n25Bloomberg\n@business\n·\n6h\nThe 13 best new restaurants in Miami, as chosen by top chefs\nbloomberg.com\nThe Best New Restaurants in Miami, as Chosen by Top Chefs\nThe 13 spots include a clubby Korean steakhouse, Spanish fare in an elevated garden, and superior sushi.\n3\n6\n25',
#   '3',
#   '6',
#   '25'),
#  ('Bloomberg',
#   '@business',
#   '2021-12-27T11:59:04.000Z',
#   "Here's why you see what you see when you open up Facebook http://bloom.bg/3st50SG (via \n@quicktake\n)\n4\n24\n62Bloomberg\n@business\n·\n6h\nHere's why you see what you see when you open up Facebook http://bloom.bg/3st50SG (via \n@quicktake\n)\n4\n24\n62",
#   '4',
#   '24',
#   '62'),
#  ('Bloomberg',
#   '@business',
#   '2021-12-27T11:51:27.000Z',
#   'A new survey shows that 72% of CEOs are worried about losing their jobs in 2022 because of business disruptions\nbloomberg.com\nFearing the Ax in 2022, CEOs Sweat Supply Chain More Than Covid\nThe C-suite is a bundle of nerves this winter. A new survey shows that 72% of chief executive officers are worried about losing their jobs in 2022 because of business disruptions, tracking closely...\n10\n36\n68Bloomberg\n@business\n·\n6h\nA new survey shows that 72% of CEOs are worried about losing their jobs in 2022 because of business disruptions\nbloomberg.com\nFearing the Ax in 2022, CEOs Sweat Supply Chain More Than Covid\nThe C-suite is a bundle of nerves this winter. A new survey shows that 72% of chief executive officers are worried about losing their jobs in 2022 because of business disruptions, tracking closely...\n10\n36\n68',
#   '10',
#   '36',
#   '68'),
#  ('Bloomberg',
#   '@business',
#   '2021-12-27T11:50:09.000Z',
#   "Hungary's forint tumbles to a record low against the euro in light post-holiday volumes https://trib.al/d5xhWun\n2\n4\n21Bloomberg\n@business\n·\n6h\nHungary's forint tumbles to a record low against the euro in light post-holiday volumes https://trib.al/d5xhWun\n2\n4\n21",
#   '2',
#   '4',
#   '21'),
#  ('Bloomberg',
#   '@business',
#   '2021-12-27T11:42:05.000Z',
#   'The best craft beers of 2021 https://trib.al/j2OC2ju via \n@luxury\nbloomberg.com\nThe 15 Best Beers We Drank This Year\nEven with our craft beer expert staying close to home, there were still plenty of inspiring, creative brews to be discovered, from the traditional to the innovative.\n1\n4\n27Bloomberg\n@business\n·\n7h\nThe best craft beers of 2021 https://trib.al/j2OC2ju via \n@luxury\nbloomberg.com\nThe 15 Best Beers We Drank This Year\nEven with our craft beer expert staying close to home, there were still plenty of inspiring, creative brews to be discovered, from the traditional to the innovative.\n1\n4\n27',
#   '1',
#   '4',
#   '27'),
#  ('Bloomberg',
#   '@business',
#   '2021-12-27T11:41:05.000Z',
#   'Italy, already suffering one of the industrialized world’s highest public debt burdens, has seen the coronavirus pandemic inflate it by 5,000 euros to 46,400 euros per capita https://trib.al/7jArpnd\n23\n83\n202Bloomberg\n@business\n·\n7h\nItaly, already suffering one of the industrialized world’s highest public debt burdens, has seen the coronavirus pandemic inflate it by 5,000 euros to 46,400 euros per capita https://trib.al/7jArpnd\n23\n83\n202',
#   '23',
#   '83',
#   '202'),
#  ('Bloomberg',
#   '@business',
#   '2021-12-27T11:34:03.000Z',
#   "Apple will likely look to better bundles and deeper integration across services as it amps up its digital media push, \n@markgurman\n explains in this week's Power On.\nbloomberg.com\nApple’s Next Step in Services Could Be New Bundles, Deeper Integration\nHey everyone, it’s Mark. The next phase of Apple’s services push is likely to include deeper integration among offerings and more bundles. Also: Apple hires Facebook’s AR/VR communications chief as...\n2\n11\n18Bloomberg\n@business\n·\n7h\nApple will likely look to better bundles and deeper integration across services as it amps up its digital media push, \n@markgurman\n explains in this week's Power On.\nbloomberg.com\nApple’s Next Step in Services Could Be New Bundles, Deeper Integration\nHey everyone, it’s Mark. The next phase of Apple’s services push is likely to include deeper integration among offerings and more bundles. Also: Apple hires Facebook’s AR/VR communications chief as...\n2\n11\n18",
#   '2',
#   '11',
#   '18'),
#  ('Bloomberg',
#   '@business',
#   '2021-12-27T11:10:34.000Z',
#   'There’s no reason to worry the rally that catapulted U.S. stocks to successive records this year will end anytime soon, according to JPMorgan strategists\nbloomberg.com\nJPMorgan Says Investors Too Bearish, Doesn’t See Stock Selloff\nThere’s no reason to fear that the rally that catapulted U.S. stocks to successive records this year will end anytime soon, according to JPMorgan Chase & Co. strategists. In fact, more investors may...\n9\n17\n51Bloomberg\n@business\n·\n7h\nThere’s no reason to worry the rally that catapulted U.S. stocks to successive records this year will end anytime soon, according to JPMorgan strategists\nbloomberg.com\nJPMorgan Says Investors Too Bearish, Doesn’t See Stock Selloff\nThere’s no reason to fear that the rally that catapulted U.S. stocks to successive records this year will end anytime soon, according to JPMorgan Chase & Co. strategists. In fact, more investors may...\n9\n17\n51',
#   '9',
#   '17',
#   '51'),
#  ('Bloomberg',
#   '@business',
#   '2021-12-27T10:50:24.000Z',
#   'Bulgarian shoppers are crossing Turkey’s western border in packed cars and buses, taking advantage of a declining Turkish lira\nbloomberg.com\nBulgarian Shoppers Find Bargains in Turkey as Lira Struggles\nEdirne, Turkey (AP) -- Bulgarian shoppers are crossing Turkey’s western border in packed cars and buses, taking advantage of a declining Turkish lira to fuel their own shopping sprees.\n8\n36\n66Bloomberg\n@business\n·\n7h\nBulgarian shoppers are crossing Turkey’s western border in packed cars and buses, taking advantage of a declining Turkish lira\nbloomberg.com\nBulgarian Shoppers Find Bargains in Turkey as Lira Struggles\nEdirne, Turkey (AP) -- Bulgarian shoppers are crossing Turkey’s western border in packed cars and buses, taking advantage of a declining Turkish lira to fuel their own shopping sprees.\n8\n36\n66',
#   '8',
#   '36',
#   '66'),
#  ('Bloomberg',
#   '@business',
#   '2021-12-27T09:20:04.000Z',
#   'A surge in renewable energy in India is set to massively increase spot power trading, according to the country’s largest electricity bourse\nbloomberg.com\nIndia’s Renewables Boom Set to Lift Power Exchange Spot Trading\nA surge in renewable energy in India is set to massively increase spot power trading, according to the country’s largest electricity bourse.\n2\n5\n23Bloomberg\n@business\n·\n9h\nA surge in renewable energy in India is set to massively increase spot power trading, according to the country’s largest electricity bourse\nbloomberg.com\nIndia’s Renewables Boom Set to Lift Power Exchange Spot Trading\nA surge in renewable energy in India is set to massively increase spot power trading, according to the country’s largest electricity bourse.\n2\n5\n23',
#   '2',
#   '5',
#   '23'),
#  ('Bloomberg',
#   '@business',
#   '2021-12-27T09:18:03.000Z',
#   'Indonesia is building a hospital that will be run in partnership with U.S.-based Mayo Clinic as part of a bid to recoup $7 billion in outbound medical tourism\nbloomberg.com\nJokowi Builds Hospital to Recoup $7 Billion in Medical Tourism\nIndonesia is building a hospital that will be run in partnership with U.S.-based Mayo Clinic as part of a bid to recoup $7 billion in outbound medical tourism.\n3\n17\n31Bloomberg\n@business\n·\n9h\nIndonesia is building a hospital that will be run in partnership with U.S.-based Mayo Clinic as part of a bid to recoup $7 billion in outbound medical tourism\nbloomberg.com\nJokowi Builds Hospital to Recoup $7 Billion in Medical Tourism\nIndonesia is building a hospital that will be run in partnership with U.S.-based Mayo Clinic as part of a bid to recoup $7 billion in outbound medical tourism.\n3\n17\n31',
#   '3',
#   '17',
#   '31'),
#  ('Bloomberg',
#   '@business',
#   '2021-12-27T09:13:55.000Z',
#   'Turkey’s lira plummets against the dollar as it strives for equilibrium in the wake of unprecedented rally last week spurred by the introduction of a new deposit tool to shield savers from a depreciating currency\nbloomberg.com\nTurkey’s Lira Slides Amid Questions Over Currency Defense Tool\nTurkey’s lira plummeted against the dollar as it strives for equilibrium in the wake of unprecedented rally last week spurred by the introduction of a new deposit tool to shield savers from a...\n2\n18\n32Bloomberg\n@business\n·\n9h\nTurkey’s lira plummets against the dollar as it strives for equilibrium in the wake of unprecedented rally last week spurred by the introduction of a new deposit tool to shield savers from a depreciating currency\nbloomberg.com\nTurkey’s Lira Slides Amid Questions Over Currency Defense Tool\nTurkey’s lira plummeted against the dollar as it strives for equilibrium in the wake of unprecedented rally last week spurred by the introduction of a new deposit tool to shield savers from a...\n2\n18\n32',
#   '2',
#   '18',
#   '32'),
#  ('Bloomberg',
#   '@business',
#   '2021-12-27T08:59:03.000Z',
#   'What markets should be most focused on is hospitalization numbers, but the problem is that accurate and timely data on this topic is hard to gather\nbloomberg.com\nOmicron’s Negative Markets Impact Has Been Dismissed Too Quickly\nThe concepts of percentages and lagged data series are leading investors toward a complacent conclusion on omicron that doesn’t yet appear justified by empirical data.\n4\n5\n12Bloomberg\n@business\n·\n9h\nWhat markets should be most focused on is hospitalization numbers, but the problem is that accurate and timely data on this topic is hard to gather\nbloomberg.com\nOmicron’s Negative Markets Impact Has Been Dismissed Too Quickly\nThe concepts of percentages and lagged data series are leading investors toward a complacent conclusion on omicron that doesn’t yet appear justified by empirical data.\n4\n5\n12',
#   '4',
#   '5',
#   '12'),
#  ('Bloomberg',
#   '@business',
#   '2021-12-27T08:55:15.000Z',
#   'The Taliban administration is working to boost exports to save the Afghan economy from collapse, with a government official saying international humanitarian aid alone won’t prevent the country from slipping deeper into poverty\nbloomberg.com\nTaliban Aims To Boost Exports to Ease Crisis As Foreign Aid Ends\nThe Taliban administration is working to boost exports to save the Afghan economy from collapse, with a government official saying international humanitarian aid alone won’t prevent the country from...\n8\n15\n24Bloomberg\n@business\n·\n9h\nThe Taliban administration is working to boost exports to save the Afghan economy from collapse, with a government official saying international humanitarian aid alone won’t prevent the country from slipping deeper into poverty\nbloomberg.com\nTaliban Aims To Boost Exports to Ease Crisis As Foreign Aid Ends\nThe Taliban administration is working to boost exports to save the Afghan economy from collapse, with a government official saying international humanitarian aid alone won’t prevent the country from...\n8\n15\n24',
#   '8',
#   '15',
#   '24'),
#  ('Bloomberg',
#   '@business',
#   '2021-12-27T08:43:04.000Z',
#   'European stocks are little changed on Monday following gains last week, as investors assess a surge of Covid-19 cases and the impact it may have on the economic recovery\nbloomberg.com\nEuropean Stock Market Rebound Stalls Amid Omicron Worries\nEuropean stocks were little changed on Monday following gains last week, as investors assess a surge of Covid-19 cases and the impact it may have on the economic recovery. The U.K. market will remain...\n3\n8\n18Bloomberg\n@business\n·\n10h\nEuropean stocks are little changed on Monday following gains last week, as investors assess a surge of Covid-19 cases and the impact it may have on the economic recovery\nbloomberg.com\nEuropean Stock Market Rebound Stalls Amid Omicron Worries\nEuropean stocks were little changed on Monday following gains last week, as investors assess a surge of Covid-19 cases and the impact it may have on the economic recovery. The U.K. market will remain...\n3\n8\n18',
#   '3',
#   '8',
#   '18'),
#  ('Bloomberg',
#   '@business',
#   '2021-12-27T08:26:30.000Z',
#   'A leading Israeli hospital will begin a study on Monday to determine the safety and efficacy of a fourth coronavirus vaccine dose\nbloomberg.com\nIsraeli Hospital to Start Fourth Covid Jab Efficacy Study\nA leading Israeli hospital will begin a study on Monday to determine the safety and efficacy of a fourth coronavirus vaccine dose.\n13\n45\n44Bloomberg\n@business\n·\n10h\nA leading Israeli hospital will begin a study on Monday to determine the safety and efficacy of a fourth coronavirus vaccine dose\nbloomberg.com\nIsraeli Hospital to Start Fourth Covid Jab Efficacy Study\nA leading Israeli hospital will begin a study on Monday to determine the safety and efficacy of a fourth coronavirus vaccine dose.\n13\n45\n44',
#   '13',
#   '45',
#   '44'),
#  ('Bloomberg',
#   '@business',
#   '2021-12-27T08:26:06.000Z',
#   'These are 2021’s best books, as picked by the top leaders in business and finance\nbloomberg.com\n2021 Best Books on Business and Leadership\nOur annual list of what the most powerful people in business read this year.\n7\n26\n100Bloomberg\n@business\n·\n10h\nThese are 2021’s best books, as picked by the top leaders in business and finance\nbloomberg.com\n2021 Best Books on Business and Leadership\nOur annual list of what the most powerful people in business read this year.\n7\n26\n100',
#   '7',
#   '26',
#   '100'),
#  ('Bloomberg',
#   '@business',
#   '2021-12-27T08:05:24.000Z',
#   'Binance receives in-principle approval from Bahrain’s central bank to be a crypto-asset service provider in the kingdom\nbloomberg.com\nBinance Gets Its First Gulf Crypto Regulatory Nod in Bahrain\nBinance Holdings Ltd. received in-principle approval from Bahrain’s central bank to be a crypto-asset service provider in the kingdom, according to a statement from the company.\n23\n113\n329Bloomberg\n@business\n·\n10h\nBinance receives in-principle approval from Bahrain’s central bank to be a crypto-asset service provider in the kingdom\nbloomberg.com\nBinance Gets Its First Gulf Crypto Regulatory Nod in Bahrain\nBinance Holdings Ltd. received in-principle approval from Bahrain’s central bank to be a crypto-asset service provider in the kingdom, according to a statement from the company.\n23\n113\n329',
#   '23',
#   '113',
#   '329'),
#  ('Bloomberg',
#   '@business',
#   '2021-12-27T07:10:44.000Z',
#   'Taiwan stocks close at a record high as a global rebound in tech hardware shares extend and retail investors continue to pile in\nbloomberg.com\nTaiwan Stocks Close at Record High on Tech Rebound, Retail Boom\nTaiwan’s equity benchmark closed at a record high as a global rebound in tech hardware shares extended and retail investors continued to pile in.\n5\n34\n60Bloomberg\n@business\n·\n11h\nTaiwan stocks close at a record high as a global rebound in tech hardware shares extend and retail investors continue to pile in\nbloomberg.com\nTaiwan Stocks Close at Record High on Tech Rebound, Retail Boom\nTaiwan’s equity benchmark closed at a record high as a global rebound in tech hardware shares extended and retail investors continued to pile in.\n5\n34\n60',
#   '5',
#   '34',
#   '60'),
#  ('Bloomberg',
#   '@business',
#   '2021-12-27T06:50:03.000Z',
#   'Year Two of the Covid-19 pandemic brought about innovations in architecture, technology, equality, climate and transportation in cities across the globe. https://trib.al/kigGdFe via \n@citylab\nbloomberg.com\n10 Ways Cities Came Back in 2021\nYear Two of the Covid-19 pandemic brought about innovations in architecture, technology, equality, climate and transportation in cities across the globe.\n2\n12\n32Bloomberg\n@business\n·\n11h\nYear Two of the Covid-19 pandemic brought about innovations in architecture, technology, equality, climate and transportation in cities across the globe. https://trib.al/kigGdFe via \n@citylab\nbloomberg.com\n10 Ways Cities Came Back in 2021\nYear Two of the Covid-19 pandemic brought about innovations in architecture, technology, equality, climate and transportation in cities across the globe.\n2\n12\n32',
#   '2',
#   '12',
#   '32'),
#  ('Bloomberg',
#   '@business',
#   '2021-12-27T06:45:37.000Z',
#   'Palm oil declines as some investors seek to lock in year-end gains, although concerns remain that floods in Malaysia will curb supplies\nbloomberg.com\nPalm Oil Declines After Four Days of Gains With Floods in Focus\nPalm oil retreated as some investors seek to lock in year-end gains, although concerns remain that floods in Malaysia will curb supplies.\n3\n14\n34Bloomberg\n@business\n·\n12h\nPalm oil declines as some investors seek to lock in year-end gains, although concerns remain that floods in Malaysia will curb supplies\nbloomberg.com\nPalm Oil Declines After Four Days of Gains With Floods in Focus\nPalm oil retreated as some investors seek to lock in year-end gains, although concerns remain that floods in Malaysia will curb supplies.\n3\n14\n34',
#   '3',
#   '14',
#   '34'),
#  ('Bloomberg',
#   '@business',
#   '2021-12-27T06:35:02.000Z',
#   '11 un-magical secrets I learned while working at Disney World ... and some of them are definitely not G-rated https://trib.al/YWGtk93 via \n@luxury\nbloomberg.com\n11 Un-Magical Secrets I Learned While Working at Disney World\n... and some of them are definitely not G-rated\n2\n8\n28Bloomberg\n@business\n·\n12h\n11 un-magical secrets I learned while working at Disney World ... and some of them are definitely not G-rated https://trib.al/YWGtk93 via \n@luxury\nbloomberg.com\n11 Un-Magical Secrets I Learned While Working at Disney World\n... and some of them are definitely not G-rated\n2\n8\n28',
#   '2',
#   '8',
#   '28'),
#  ('Bloomberg',
#   '@business',
#   '2021-12-27T06:20:39.000Z',
#   'LATEST: Australia posts more than 10,000 daily Covid cases for the first time since the pandemic began, as New South Wales reports its first omicron death\nbloomberg.com\nAustralia’s Daily Covid Cases Surge Past 10,000 for First Time\nAustralia reported more than 10,000 daily Covid-19 cases for the first time since the start of the pandemic amid the rapid spread of the omicron strain.\n7\n30\n57Bloomberg\n@business\n·\n12h\nLATEST: Australia posts more than 10,000 daily Covid cases for the first time since the pandemic began, as New South Wales reports its first omicron death\nbloomberg.com\nAustralia’s Daily Covid Cases Surge Past 10,000 for First Time\nAustralia reported more than 10,000 daily Covid-19 cases for the first time since the start of the pandemic amid the rapid spread of the omicron strain.\n7\n30\n57',
#   '7',
#   '30',
#   '57'),
#  ('Bloomberg',
#   '@business',
#   '2021-12-27T06:20:05.000Z',
#   'Actress Amber Heard has named her new dog after Australia’s outspoken Deputy Prime Minister Barnaby Joyce, following a battle with the politician over pet quarantine during a visit to the country in 2015\nbloomberg.com\nAmber Heard Names Dog After Australia’s Deputy PM Following Spat\nActress Amber Heard has named her new dog after Australia’s outspoken Deputy Prime Minister Barnaby Joyce, following a battle with the politician over pet quarantine during a visit to the country in...\n19\n10\n68Bloomberg\n@business\n·\n12h\nActress Amber Heard has named her new dog after Australia’s outspoken Deputy Prime Minister Barnaby Joyce, following a battle with the politician over pet quarantine during a visit to the country in 2015\nbloomberg.com\nAmber Heard Names Dog After Australia’s Deputy PM Following Spat\nActress Amber Heard has named her new dog after Australia’s outspoken Deputy Prime Minister Barnaby Joyce, following a battle with the politician over pet quarantine during a visit to the country in...\n19\n10\n68',
#   '19',
#   '10',
#   '68'),
#  ('Bloomberg',
#   '@business',
#   '2021-12-27T06:17:04.000Z',
# ...
#   '15',
#   '15',
#   '21'),
#  ('Bloomberg',
#   '@business',
#   '2021-12-23T01:53:02.000Z',
#   'SciPlay, the maker of mobile and web games such as Jackpot Party Casino, fell as much as 21% in extended trading after ending talks to sell out to majority owner Scientific Games\nbloomberg.com\nSciPlay Plunges 21% After Sale Talks With Scientific Games End\nSciPlay Corp., the maker of mobile and web games such as Jackpot Party Casino, fell as much as 21% in extended trading after ending talks to sell out to majority owner Scientific Games Corp., a large...\n2\n7\n9Bloomberg\n@business\n·\nDec 23\nSciPlay, the maker of mobile and web games such as Jackpot Party Casino, fell as much as 21% in extended trading after ending talks to sell out to majority owner Scientific Games\nbloomberg.com\nSciPlay Plunges 21% After Sale Talks With Scientific Games End\nSciPlay Corp., the maker of mobile and web games such as Jackpot Party Casino, fell as much as 21% in extended trading after ending talks to sell out to majority owner Scientific Games Corp., a large...\n2\n7\n9',
#   '2',
#   '7',
#   '9'),
#  ('Bloomberg',
#   '@business',
#   '2021-12-23T01:49:01.000Z',
#   'The developers of a ritzy Manhattan skyscraper say the condo board is trying to squeeze money out of them with a lawsuit that claims bogus design flaws\nbloomberg.com\nRitzy NYC Tower Developer Says Residents’ Lawsuit ‘Ill-Advised’\nThe developers of a Manhattan skyscraper that has become one of New York City’s toniest residences said the condo board is trying to squeeze money out of them with a lawsuit that claims bogus design...\n2\n12\n14Bloomberg\n@business\n·\nDec 23\nThe developers of a ritzy Manhattan skyscraper say the condo board is trying to squeeze money out of them with a lawsuit that claims bogus design flaws\nbloomberg.com\nRitzy NYC Tower Developer Says Residents’ Lawsuit ‘Ill-Advised’\nThe developers of a Manhattan skyscraper that has become one of New York City’s toniest residences said the condo board is trying to squeeze money out of them with a lawsuit that claims bogus design...\n2\n12\n14',
#   '2',
#   '12',
#   '14'),
#  ('Bloomberg',
#   '@business',
#   '2021-12-23T01:41:02.000Z',
#   'Divesting from oil and gas has been a profitable trade for the last couple of years. Now, for the first time since 2016, investors who held on to energy shares are poised to outperform the broader market\nbloomberg.com\nEnergy Beats the Broader Market for the First Time in Five Years\nDivesting from oil and gas has been a profitable trade for the last couple of years. Now, for the first time since 2016, investors who held on to energy shares are poised to outperform the broader...\n9\n16\n24Bloomberg\n@business\n·\nDec 23\nDivesting from oil and gas has been a profitable trade for the last couple of years. Now, for the first time since 2016, investors who held on to energy shares are poised to outperform the broader market\nbloomberg.com\nEnergy Beats the Broader Market for the First Time in Five Years\nDivesting from oil and gas has been a profitable trade for the last couple of years. Now, for the first time since 2016, investors who held on to energy shares are poised to outperform the broader...\n9\n16\n24',
#   '9',
#   '16',
#   '24'),
#  ('Bloomberg',
#   '@business',
#   '2021-12-23T01:40:08.000Z',
#   'Quebec expects its daily Covid infections tally to jump 40% in just 24 hours\nbloomberg.com\nQuebec Sees 40% Jump in Covid Cases in 24 Hours\nQuebec expects its daily Covid infections tally to jump 40% in just 24 hours, confirming its status as Canada’s virus hot spot once again as it multiplies measures to slow down hospitalizations.\n15\n38\n40Bloomberg\n@business\n·\nDec 23\nQuebec expects its daily Covid infections tally to jump 40% in just 24 hours\nbloomberg.com\nQuebec Sees 40% Jump in Covid Cases in 24 Hours\nQuebec expects its daily Covid infections tally to jump 40% in just 24 hours, confirming its status as Canada’s virus hot spot once again as it multiplies measures to slow down hospitalizations.\n15\n38\n40',
#   '15',
#   '38',
#   '40'),
#  ('Bloomberg',
#   '@business',
#   '2021-12-22T23:42:08.000Z',
#   "Booster shots are helping some countries weather omicron better than others.\n\nSee how your country is faring in Bloomberg's latest Covid Resilience Ranking \nbloomberg.com\nThe Best and Worst Places to Be in Covid as Winter Meets Omicron\nBloomberg measured travel, vaccine coverage, lockdown disruption and mortality rates.\n9\n14\n21Bloomberg\n@business\n·\nDec 23\nBooster shots are helping some countries weather omicron better than others.\n\nSee how your country is faring in Bloomberg's latest Covid Resilience Ranking \nbloomberg.com\nThe Best and Worst Places to Be in Covid as Winter Meets Omicron\nBloomberg measured travel, vaccine coverage, lockdown disruption and mortality rates.\n9\n14\n21",
#   '9',
#   '14',
#   '21'),
#  ('Bloomberg',
#   '@business',
#   '2021-12-22T23:37:03.000Z',
#   'Enthusiasts believe that crypto isn’t just for sending money or speculating with, but could be used to build a whole new web. Enter: Web3\nbloomberg.com\nWhat You Need to Know About Web3, Crypto’s Attempt to Reinvent the Internet\nEnthusiasts say tokens can change computing. Is this the real deal or vaporware?\n9\n20\n46Bloomberg\n@business\n·\nDec 23\nEnthusiasts believe that crypto isn’t just for sending money or speculating with, but could be used to build a whole new web. Enter: Web3\nbloomberg.com\nWhat You Need to Know About Web3, Crypto’s Attempt to Reinvent the Internet\nEnthusiasts say tokens can change computing. Is this the real deal or vaporware?\n9\n20\n46',
#   '9',
#   '20',
#   '46'),
#  ('Bloomberg',
#   '@business',
#   '2021-12-22T23:31:07.000Z',
#   'Covid-19 test positivity rates at New York City’s Rikers Island correctional facility soared to over 17%, prompting the head of the city’s Department of Correction to ask the courts to help reduce the jail population amid the rapid spread of omicron\nbloomberg.com\nNYC Sees Jail ‘Crisis’ on Positive-Test Rates Over 17% at Rikers\nDepartment of Correction chief asks courts, public defenders to help limit jail population amid the rapid spread of omicron\n4\n13\n20Bloomberg\n@business\n·\nDec 23\nCovid-19 test positivity rates at New York City’s Rikers Island correctional facility soared to over 17%, prompting the head of the city’s Department of Correction to ask the courts to help reduce the jail population amid the rapid spread of omicron\nbloomberg.com\nNYC Sees Jail ‘Crisis’ on Positive-Test Rates Over 17% at Rikers\nDepartment of Correction chief asks courts, public defenders to help limit jail population amid the rapid spread of omicron\n4\n13\n20',
#   '4',
#   '13',
#   '20'),
#  ('Bloomberg',
#   '@business',
#   '2021-12-22T23:30:13.000Z',
#   'Nonprofit Covax distributes Covid vaccines to mostly poor countries.\n\nIts message to rich nations: No one is safe until everyone is https://trib.al/AYByns3 via \n@BW\nbloomberg.com\nThe World’s Best Hope to End the Pandemic Still Needs More Doses\nCovax, which distributes Covid vaccines to mostly poor countries, has been saying for a year no one is safe until everyone is.\n3\n18\n34Bloomberg\n@business\n·\nDec 23\nNonprofit Covax distributes Covid vaccines to mostly poor countries.\n\nIts message to rich nations: No one is safe until everyone is https://trib.al/AYByns3 via \n@BW\nbloomberg.com\nThe World’s Best Hope to End the Pandemic Still Needs More Doses\nCovax, which distributes Covid vaccines to mostly poor countries, has been saying for a year no one is safe until everyone is.\n3\n18\n34',
#   '3',
#   '18',
#   '34'),
#  ('Bloomberg',
#   '@business',
#   '2021-12-22T23:24:03.000Z',
#   "Veterans of past Wall Street booms suggest that, somehow, this one doesn't feel so good\n\nRead the Big Take \nbloomberg.com\nWall Street Ends Crazy Year With Existential Angst and Big Bonuses\nThe biggest U.S. banks are making more money than ever, but finance veterans are ‘unsettled and ill at ease.’\n6\n13\n18Bloomberg\n@business\n·\nDec 23\nVeterans of past Wall Street booms suggest that, somehow, this one doesn't feel so good\n\nRead the Big Take \nbloomberg.com\nWall Street Ends Crazy Year With Existential Angst and Big Bonuses\nThe biggest U.S. banks are making more money than ever, but finance veterans are ‘unsettled and ill at ease.’\n6\n13\n18",
#   '6',
#   '13',
#   '18'),
#  ('Bloomberg',
#   '@business',
#   '2021-12-22T23:20:05.000Z',
#   'Wealthy Asians are pouring money at a record pace into alternative assets through private banks and high-end investment firms\nbloomberg.com\nHedge Funds and Private Equity Lure Billions From Rich Asians\n5\n26\n50Bloomberg\n@business\n·\nDec 23\nWealthy Asians are pouring money at a record pace into alternative assets through private banks and high-end investment firms\nbloomberg.com\nHedge Funds and Private Equity Lure Billions From Rich Asians\n5\n26\n50',
#   '5',
#   '26',
#   '50'),
#  ('Bloomberg',
#   '@business',
#   '2021-12-22T23:09:02.000Z',
#   'The Consumer Technology Association is pushing ahead with plans to host the annual CES technology conference in person next month in Las Vegas\nbloomberg.com\nCES Presses Ahead With In-Person Tech Conference Despite Dropouts\n4\n9\n16Bloomberg\n@business\n·\nDec 23\nThe Consumer Technology Association is pushing ahead with plans to host the annual CES technology conference in person next month in Las Vegas\nbloomberg.com\nCES Presses Ahead With In-Person Tech Conference Despite Dropouts\n4\n9\n16',
#   '4',
#   '9',
#   '16'),
#  ('Bloomberg',
#   '@business',
#   '2021-12-22T23:05:42.000Z',
#   'Apple temporarily shuttered at least seven retail stores in the U.S. and Canada over the past day as Covid-19 cases among employees surge\nbloomberg.com\nApple Shuts at Least Seven Stores Since Tuesday Amid Covid Surge\nApple Inc. temporarily shuttered at least seven retail stores in the U.S. and Canada over the past day as Covid-19 cases among employees surge.\n5\n28\n42Bloomberg\n@business\n·\nDec 23\nApple temporarily shuttered at least seven retail stores in the U.S. and Canada over the past day as Covid-19 cases among employees surge\nbloomberg.com\nApple Shuts at Least Seven Stores Since Tuesday Amid Covid Surge\nApple Inc. temporarily shuttered at least seven retail stores in the U.S. and Canada over the past day as Covid-19 cases among employees surge.\n5\n28\n42',
#   '5',
#   '28',
#   '42'),
#  ('Bloomberg Retweeted',
#   '@bopinion',
#   '2021-12-22T22:45:25.000Z',
#   'From crypto to Covid, 2021 was anything but normal. Join us for a year-end Editorial Board bonanza at 7 p.m. ET on \n@TwitterSpaces\n!\n@RobGeorge\n will be joined by \n@maryad5\n, \n@FSBarry\n, \n@mrkwhths\n, \n@romeshratnesar\n and \n@ClaraDFMarques\nDec 23·Bloomberg Opinion·53:50\nThe Highs & Lows of 2021, According to the Editors\n+5\nPlay recording\n27\n16\n22Bloomberg Retweeted',
#   '27',
#   '16',
#   '22'),
#  ('Bloomberg',
#   '@business',
#   '2021-12-22T22:53:09.000Z',
#   'Jurors in Ghislaine Maxwell’s trial asked for transcripts of testimony from a woman accusing her of abuse and the house manager for the socialite’s Palm Beach mansion with Jeffrey Epstein\nbloomberg.com\nMaxwell Faces Grim 60th as Jury Goes on Break Without Verdict\nGhislaine Maxwell will mark her 60th birthday in jail.\n6\n15\n37Bloomberg\n@business\n·\nDec 22\nJurors in Ghislaine Maxwell’s trial asked for transcripts of testimony from a woman accusing her of abuse and the house manager for the socialite’s Palm Beach mansion with Jeffrey Epstein\nbloomberg.com\nMaxwell Faces Grim 60th as Jury Goes on Break Without Verdict\nGhislaine Maxwell will mark her 60th birthday in jail.\n6\n15\n37',
#   '6',
#   '15',
#   '37'),
#  ('Bloomberg',
#   '@business',
#   '2021-12-22T22:27:06.000Z',
#   'Inside the 30-year hunt for a $10 billion fortune\nbloomberg.com\nWhere Did Marcos Hide His $10 Billion Fortune?\nAlmost 30 years ago, an American court ruled that victims of the Ferdinand Marcos regime in the Philippines should be compensated. The money was very well hidden. \n11\n25\n71Bloomberg\n@business\n·\nDec 22\nInside the 30-year hunt for a $10 billion fortune\nbloomberg.com\nWhere Did Marcos Hide His $10 Billion Fortune?\nAlmost 30 years ago, an American court ruled that victims of the Ferdinand Marcos regime in the Philippines should be compensated. The money was very well hidden. \n11\n25\n71',
#   '11',
#   '25',
#   '71'),
#  ('Bloomberg',
#   '@business',
#   '2021-12-22T22:26:04.000Z',
#   'Boss want you back in the office? Here’s how to keep a hybrid arrangement beneficial to everyone https://trib.al/KbDKrJh via \n@BW\nbloomberg.com\nFour Ways to Keep Working From Home When the Boss Wants You Back\nManaging a hybrid schedule requires more care as companies start to ask employees to return to the office.\n1\n12\n22Bloomberg\n@business\n·\nDec 22\nBoss want you back in the office? Here’s how to keep a hybrid arrangement beneficial to everyone https://trib.al/KbDKrJh via \n@BW\nbloomberg.com\nFour Ways to Keep Working From Home When the Boss Wants You Back\nManaging a hybrid schedule requires more care as companies start to ask employees to return to the office.\n1\n12\n22',
#   '1',
#   '12',
#   '22'),
#  ('Bloomberg Retweeted',
#   '@wealth',
#   '2021-12-22T21:58:03.000Z',
#   'Is it time to start making a financial plan for the virtual world?\nbloomberg.com\nBloomberg Wealth: Your Money in the Metaverse\nWhat’s your financial plan for the metaverse?\n3\n9\n19Bloomberg Retweeted',
#   '3',
#   '9',
#   '19'),
#  ('Bloomberg',
#   '@business',
#   '2021-12-22T22:09:04.000Z',
#   'More American males aged 25-34 are living in a parent’s home, and fewer are participating in the labor force https://trib.al/hl72iLZ via \n@BW\nbloomberg.com\nFewer Young Men Are in the Labor Force. More Are Living at Home\nFor 25- to 34-year-olds, the two trends add up to a failure to launch.\n23\n91\n113Bloomberg\n@business\n·\nDec 22\nMore American males aged 25-34 are living in a parent’s home, and fewer are participating in the labor force https://trib.al/hl72iLZ via \n@BW\nbloomberg.com\nFewer Young Men Are in the Labor Force. More Are Living at Home\nFor 25- to 34-year-olds, the two trends add up to a failure to launch.\n23\n91\n113',
#   '23',
#   '91',
#   '113'),
#  ('Bloomberg',
#   '@business',
#   '2021-12-22T22:04:38.000Z',
#   'How to keep life-saving masks in a deadly human pandemic from becoming a death sentence for marine life in the ocean https://trib.al/YUKOmbC via \n@BW\nbloomberg.com\nThe Quest for a Disposable Mask That Won’t Pollute\nCompanies experiment with ways to make the plastic used in most face coverings biodegradable, so it won’t threaten marine life.\n3\n14\n19Bloomberg\n@business\n·\nDec 22\nHow to keep life-saving masks in a deadly human pandemic from becoming a death sentence for marine life in the ocean https://trib.al/YUKOmbC via \n@BW\nbloomberg.com\nThe Quest for a Disposable Mask That Won’t Pollute\nCompanies experiment with ways to make the plastic used in most face coverings biodegradable, so it won’t threaten marine life.\n3\n14\n19',
#   '3',
#   '14',
#   '19'),
#  ('Bloomberg',
#   '@business',
#   '2021-12-22T22:03:03.000Z',
#   'The House committee investigating the Jan. 6 insurrection at the U.S. Capitol asked Representative Jim Jordan to voluntarily agree to a meeting\nbloomberg.com\nGOP’s Jim Jordan Is Asked by Jan. 6 Panel to Explain Trump Talks\nThe House committee investigating the Jan. 6 insurrection at the U.S. Capitol on Wednesday asked Ohio Representative Jim Jordan to voluntarily agree to a meeting.\n13\n16\n41Bloomberg\n@business\n·\nDec 22\nThe House committee investigating the Jan. 6 insurrection at the U.S. Capitol asked Representative Jim Jordan to voluntarily agree to a meeting\nbloomberg.com\nGOP’s Jim Jordan Is Asked by Jan. 6 Panel to Explain Trump Talks\nThe House committee investigating the Jan. 6 insurrection at the U.S. Capitol on Wednesday asked Ohio Representative Jim Jordan to voluntarily agree to a meeting.\n13\n16\n41',
#   '13',
#   '16',
#   '41')]

# %%
with open('Bloomberg_tweets.csv', 'w', newline = '', encoding = 'utf-8') as f:
    header = ['UserName', 'Handle', 'Timestamp', 'Comments', 'Likes', 'Retweets', 'Text']
    writer = csv.writer(f)
    writer.writerow(header)
    writer.writerows(data)
